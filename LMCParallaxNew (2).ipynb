# %%
from dl import authClient as ac, queryClient as qc, storeClient as sc, helpers
import pylab as plt
import numpy as np

# %%
token=ac.login('mgkadrmas')

# %%
def LMCParallax (ra,dec,radius):
    #take query
    res=qc.query(token,sql='select * from gaia_dr2.gaia_source where q3c_radial_query(ra,dec,'+str(ra)+','+str(dec)+','+str(radius)+')')
    df=helpers.utils.convert(res,'table')
    good1 = (df['bp_rp'].data>=0.92) & (df['bp_rp'].data<=2.5) & (df['phot_g_mean_mag']<20.0) & (df['phot_g_mean_mag']>=(-5.0*df['bp_rp']+24.0)) & (df['phot_g_mean_mag']<=(-5.0*df['bp_rp']+27.0)) & (np.abs(df['parallax'])<=0.2)
    medpmra=np.median(df['pmra'][good1])
    medpmdec=np.median(df['pmdec'][good1])
    pndist=np.sqrt((df['pmra']-medpmra)**2 + (df['pmdec']-medpmdec)**2)
    good2 = (df['bp_rp'].data>=0.92) & (df['bp_rp'].data<=2.5) & (df['phot_g_mean_mag']<19.0) & (df['phot_g_mean_mag']>=(-5.0*df['bp_rp']+24.0)) & (df['phot_g_mean_mag']<=(-5.0*df['bp_rp']+27.0)) & (np.abs(df['parallax'])<=0.2) &(pndist<=2.0)
    medplx=np.median(df['parallax'][good2])+0.030112982075019102 #right mean distance? 
    ngood=np.sum(good2)
    print(ra, dec, radius, ngood, medplx)
    return (ngood, medplx)

# %%
radius=0.5
dtype = np.dtype([('ra',float),('dec',float),('radius',float),('ngood',int),('parallax',float)])
cat = np.zeros([25,13],dtype=dtype)
for i in range (25):
    ra=i+67
    for j in range (13):
        dec=j-76
        (ngood, medplx) = LMCParallax(ra,dec,radius) 
        cat[i,j]['ra']=ra
        cat[i,j]['dec']=dec
        cat[i,j]['radius']=radius
        cat[i,j]['ngood']=ngood
        cat[i,j]['parallax']=medplx
# Out:
# /data0/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater_equal
#   """
# /data0/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in less_equal
#   """
# /data0/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in greater_equal
#   if __name__ == '__main__':
# /data0/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in less_equal
#   if __name__ == '__main__':
# 67 -76 0.5 286 0.021558689700189253
# 67 -75 0.5 711 0.0251415706450357
# 67 -74 0.5 1273 0.015969560427023903
# 67 -73 0.5 1961 0.0127590595593676
# 67 -72 0.5 2299 0.018615001963071302
# 67 -71 0.5 2288 0.015342110427128752
# 67 -70 0.5 2706 0.015186008855331851
# 67 -69 0.5 2747 0.016887255950181
# 67 -68 0.5 2445 0.019013789380360503
# 67 -67 0.5 1505 0.0258288180346246
# 67 -66 0.5 703 0.0190934112731988
# 67 -65 0.5 318 0.01950937591365705
# 67 -64 0.5 206 0.009082809328087502
# 68 -76 0.5 345 0.020462416815461203
# 68 -75 0.5 1035 0.0188669264347818
# 68 -74 0.5 1801 0.015167081469124702
# 68 -73 0.5 2586 0.014630378581483252
# 68 -72 0.5 3079 0.0228611407433471
# 68 -71 0.5 3459 0.013280414699172401
# 68 -70 0.5 4686 0.014619264209835503
# 68 -69 0.5 4440 0.014517448251234152
# 68 -68 0.5 3797 0.0185724338871475
# 68 -67 0.5 2427 0.0220894763444748
# 68 -66 0.5 1177 0.022112821334573804
# 68 -65 0.5 499 0.014489176070773801
# 68 -64 0.5 280 0.02213969496543205
# 69 -76 0.5 422 0.031527146308013
# 69 -75 0.5 1444 0.01991318089731225
# 69 -74 0.5 2513 0.0184724832655477
# 69 -73 0.5 3472 0.014517050142765152
# 69 -72 0.5 4171 0.021447446379135204
# 69 -71 0.5 5175 0.011756362680063501
# 69 -70 0.5 6728 0.011942328565055501
# 69 -69 0.5 6467 0.011028823600222303
# 69 -68 0.5 5264 0.019954301699808052
# 69 -67 0.5 3488 0.020529471499456303
# 69 -66 0.5 2019 0.0267480050566442
# 69 -65 0.5 842 0.0242432968183231
# 69 -64 0.5 380 0.031651054894354505
# 70 -76 0.5 520 0.02780329385895365
# 70 -75 0.5 1917 0.020584140087008502
# 70 -74 0.5 3339 0.020792834232412002
# 70 -73 0.5 4674 0.015167312865137002
# 70 -72 0.5 5724 0.02036097486910825
# 70 -71 0.5 6763 0.011756362680063501
# 70 -70 0.5 8029 0.012845085893749702
# 70 -69 0.5 8126 0.014551095163031153
# 70 -68 0.5 6731 0.0167755940999968
# 70 -67 0.5 4563 0.016416356239836304
# 70 -66 0.5 2971 0.021332570908310602
# 70 -65 0.5 1365 0.0281630738394123
# 70 -64 0.5 552 0.030603988994299003
# 71 -76 0.5 674 0.020588003703561904
# 71 -75 0.5 2415 0.019857031328399805
# 71 -74 0.5 4200 0.022166967176579552
# 71 -73 0.5 6109 0.0191217608594322
# 71 -72 0.5 7477 0.020049984691517204
# 71 -71 0.5 8156 0.014920098799394552
# 71 -70 0.5 9436 0.012833703093175799
# 71 -69 0.5 9727 0.014938178147335002
# 71 -68 0.5 8620 0.01095620047599075
# 71 -67 0.5 5440 0.0157022342318213
# 71 -66 0.5 3823 0.0222524470699769
# 71 -65 0.5 2044 0.022330356253559402
# 71 -64 0.5 930 0.02629225469296545
# 72 -76 0.5 890 0.019466849671589903
# 72 -75 0.5 3187 0.0203009187483009
# 72 -74 0.5 5080 0.025881359471188
# 72 -73 0.5 7589 0.0240310231216979
# 72 -72 0.5 9014 0.019423989064368104
# 72 -71 0.5 9471 0.014058338830967004
# 72 -70 0.5 11506 0.016548586753924153
# 72 -69 0.5 11787 0.015561684087626902
# 72 -68 0.5 10921 0.013653600699457601
# 72 -67 0.5 6904 0.018577958271029503
# 72 -66 0.5 4932 0.01980690985426665
# 72 -65 0.5 2850 0.015408877069973652
# 72 -64 0.5 1415 0.019426806234648104
# 73 -76 0.5 1062 0.021836227980863602
# 73 -75 0.5 3957 0.018916752465365304
# 73 -74 0.5 5939 0.025388271428882503
# 73 -73 0.5 8510 0.025022911922335654
# 73 -72 0.5 9568 0.0179640406365624
# 73 -71 0.5 10358 0.011640947192645603
# 73 -70 0.5 13977 0.0172309881853894
# 73 -69 0.5 14684 0.018549676994370653
# 73 -68 0.5 14087 0.017002495851681402
# 73 -67 0.5 8742 0.0154633566174662
# 73 -66 0.5 5967 0.013088171437447203
# 73 -65 0.5 3560 0.0144608160845026
# 73 -64 0.5 1967 0.018402790207847804
# 74 -76 0.5 1199 0.014319819436073702
# 74 -75 0.5 4767 0.016526749333448002
# 74 -74 0.5 6519 0.0244077433572496
# 74 -73 0.5 9143 0.0238572020146247
# 74 -72 0.5 9709 0.017398990110353202
# 74 -71 0.5 11780 0.015294340318299402
# 74 -70 0.5 17571 0.0186425692356968
# 74 -69 0.5 19118 0.02039296356063485
# 74 -68 0.5 16736 0.01825464302416985
# 74 -67 0.5 11006 0.01958341663641885
# 74 -66 0.5 6585 0.015808662387327303
# 74 -65 0.5 4339 0.0201046639346618
# 74 -64 0.5 2599 0.015392294806565602
# 75 -76 0.5 1508 0.019430449785047252
# 75 -75 0.5 5431 0.020144563795480103
# 75 -74 0.5 6852 0.023134797492284552
# 75 -73 0.5 9126 0.022368814819799854
# 75 -72 0.5 10367 0.018209760268126103
# 75 -71 0.5 13772 0.0190259955198366
# 75 -70 0.5 21550 0.0194820392784959
# 75 -69 0.5 22501 0.0223388344568303
# 75 -68 0.5 18583 0.018228685030495503
# 75 -67 0.5 13532 0.02193406464766925
# 75 -66 0.5 7773 0.0165319952627474
# 75 -65 0.5 5150 0.02184422502285975
# 75 -64 0.5 3133 0.0193001614914255
# 76 -76 0.5 1726 0.019563069655343053
# 76 -75 0.5 5908 0.0214839156409275
# 76 -74 0.5 6845 0.023022961581984202
# 76 -73 0.5 9048 0.020659497618195653
# 76 -72 0.5 11518 0.018984160715818703
# 76 -71 0.5 15326 0.01897362717966805
# 76 -70 0.5 25220 0.017964616313227953
# 76 -69 0.5 23085 0.017867131242797502
# 76 -68 0.5 19313 0.0143154433948636
# 76 -67 0.5 14236 0.01847905927158315
# 76 -66 0.5 9201 0.0171170604660772
# 76 -65 0.5 5724 0.021585507192681253
# 76 -64 0.5 3599 0.021523573783181503
# 77 -76 0.5 2041 0.023795684841579304
# 77 -75 0.5 6125 0.021236221342264
# 77 -74 0.5 6515 0.021901330564495402
# 77 -73 0.5 9106 0.0226026063653832
# 77 -72 0.5 13044 0.0171416926606381
# 77 -71 0.5 17504 0.015569637183616751
# 77 -70 0.5 28815 0.013393417778210803
# 77 -69 0.5 23824 0.013976426881040501
# 77 -68 0.5 20428 0.015813526447889054
# 77 -67 0.5 14588 0.017336836278879702
# 77 -66 0.5 10191 0.015430652771860502
# 77 -65 0.5 6072 0.011079291346657551
# 77 -64 0.5 3992 0.020305536657038853
# 78 -76 0.5 2267 0.0229040630363313
# 78 -75 0.5 6073 0.020658663576009303
# 78 -74 0.5 6343 0.019228503865627904
# 78 -73 0.5 9493 0.021711058323926002
# 78 -72 0.5 14607 0.014408061127825902
# 78 -71 0.5 20928 0.014616759696351903
# 78 -70 0.5 32277 0.015539722741514002
# 78 -69 0.5 26060 0.016945081062921502
# 78 -68 0.5 21372 0.017271798884089952
# 78 -67 0.5 14034 0.009990745717128952
# 78 -66 0.5 10454 0.0086852415283846
# 78 -65 0.5 6735 0.0163415428579581
# 78 -64 0.5 4544 0.0310872293406521
# 79 -76 0.5 2393 0.020000000000000004
# 79 -75 0.5 5883 0.0198590239109758
# 79 -74 0.5 6241 0.021736366520485904
# 79 -73 0.5 10007 0.0188413519082923
# 79 -72 0.5 16555 0.0143565880592782
# 79 -71 0.5 23498 0.01633469141110895
# 79 -70 0.5 31552 0.016833623371524952
# 79 -69 0.5 26008 0.011244428198947602
# 79 -68 0.5 20211 0.0086527961576668
# 79 -67 0.5 13422 0.005482231814742552
# 79 -66 0.5 10165 0.013328393753430402
# 79 -65 0.5 7446 0.017572050033555452
# 79 -64 0.5 5012 0.031159747649169952
# 80 -76 0.5 2607 0.0229639330575826
# 80 -75 0.5 5783 0.0218740019512978
# 80 -74 0.5 6034 0.023679273053269802
# 80 -73 0.5 10247 0.0186176958868364
# 80 -72 0.5 17719 0.0157927165326157
# 80 -71 0.5 25583 0.0171318500082508
# 80 -70 0.5 28227 0.011094591601460303
# 80 -69 0.5 25447 0.0029285186050813025
# 80 -68 0.5 17374 0.0097256749765019
# 80 -67 0.5 13625 0.016410837477670102
# 80 -66 0.5 10269 0.013813929871800301
# 80 -65 0.5 8157 0.010725021403894502
# 80 -64 0.5 5570 0.03211734266251315
# 81 -76 0.5 2580 0.02660226262213245
# 81 -75 0.5 5863 0.024753267081128703
# 81 -74 0.5 6114 0.023085876453396402
# 81 -73 0.5 10489 0.017974357935776904
# 81 -72 0.5 18686 0.0143795924728051
# 81 -71 0.5 26684 0.0143473991121244
# 81 -70 0.5 25510 0.0038488592330446526
# 81 -69 0.5 25096 0.004858267733432103
# 81 -68 0.5 16370 0.022225283083811803
# 81 -67 0.5 13220 0.019249535558044054
# 81 -66 0.5 9563 0.014046261841714501
# 81 -65 0.5 8550 0.014188423982024755
# 81 -64 0.5 5987 0.0312639054497131
# 82 -76 0.5 2481 0.027110542338261004
# 82 -75 0.5 6079 0.025876174283580203
# 82 -74 0.5 6248 0.021419042200399002
# 82 -73 0.5 10518 0.015126797835489453
# 82 -72 0.5 20178 0.0161103817373381
# 82 -71 0.5 26878 0.0149408299696498
# 82 -70 0.5 24351 0.004530666370049601
# 82 -69 0.5 23329 0.014788631724015202
# 82 -68 0.5 16037 0.026795208347295502
# 82 -67 0.5 12135 0.015220471351504502
# 82 -66 0.5 9856 0.018735248284685802
# 82 -65 0.5 8864 0.02178410796568065
# 82 -64 0.5 6063 0.030548689398598502
# 83 -76 0.5 2233 0.024840371721252502
# 83 -75 0.5 6392 0.024778897532177702
# 83 -74 0.5 6443 0.0186365775221266
# 83 -73 0.5 10395 0.015796162119586205
# 83 -72 0.5 20825 0.016892154758365904
# 83 -71 0.5 26589 0.013418317014275202
# 83 -70 0.5 25614 0.0119930053871397
# 83 -69 0.5 19561 0.022330392328748602
# 83 -68 0.5 14590 0.02526440309984395
# 83 -67 0.5 11617 0.017011611556171
# 83 -66 0.5 9973 0.021155435280877603
# 83 -65 0.5 8778 0.0280293858717334
# 83 -64 0.5 6096 0.026959664899291552
# 84 -76 0.5 1961 0.0260869254839324
# 84 -75 0.5 6228 0.022810229764514602
# 84 -74 0.5 5990 0.018489046335260353
# 84 -73 0.5 9535 0.017828474353001403
# 84 -72 0.5 20622 0.015826184128056454
# 84 -71 0.5 27345 0.017710872067025003
# 84 -70 0.5 26584 0.02119718387978195
# 84 -69 0.5 16370 0.0226736448747984
# 84 -68 0.5 14786 0.02514705631474435
# 84 -67 0.5 11154 0.023547950896146853
# 84 -66 0.5 9676 0.022758052653414303
# 84 -65 0.5 8759 0.0268011508954431
# 84 -64 0.5 6061 0.0237258032476165
# 85 -76 0.5 1776 0.025181531360669654
# 85 -75 0.5 5893 0.0237737189965568
# 85 -74 0.5 5428 0.01762620972433465
# 85 -73 0.5 8431 0.0172067044622025
# 85 -72 0.5 19299 0.014832790403074302
# 85 -71 0.5 28378 0.025883725430006253
# 85 -70 0.5 25900 0.022642743252372755
# 85 -69 0.5 14588 0.019748048038738402
# 85 -68 0.5 15104 0.0300156979563993
# 85 -67 0.5 10202 0.0281930440428787
# 85 -66 0.5 10050 0.019974219347857602
# 85 -65 0.5 8457 0.027142108887545903
# 85 -64 0.5 6053 0.026361918600399402
# 86 -76 0.5 1615 0.0261540383030028
# 86 -75 0.5 5354 0.022710198308434952
# 86 -74 0.5 5212 0.018062266718272754
# 86 -73 0.5 7537 0.0138909035831133
# 86 -72 0.5 17111 0.018627027026184705
# 86 -71 0.5 26645 0.0271408439015498
# 86 -70 0.5 23601 0.0180741440266904
# 86 -69 0.5 14801 0.024727778496291403
# 86 -68 0.5 13196 0.0317613467835134
# 86 -67 0.5 9000 0.025595221349423502
# 86 -66 0.5 9848 0.02078732634186725
# 86 -65 0.5 8089 0.0304165570968078
# 86 -64 0.5 6099 0.0218264207346898
# 87 -76 0.5 1364 0.026441917611980253
# 87 -75 0.5 4827 0.022151176313708602
# 87 -74 0.5 5365 0.014987407047313302
# 87 -73 0.5 6881 0.018489973813499802
# 87 -72 0.5 13507 0.024648993574704903
# 87 -71 0.5 22681 0.0209571351799342
# 87 -70 0.5 20613 0.0211334061772497
# 87 -69 0.5 13880 0.02599722509571315
# 87 -68 0.5 11194 0.02667840749353105
# 87 -67 0.5 8086 0.025786730600332104
# 87 -66 0.5 8999 0.0252123257644304
# 87 -65 0.5 7788 0.024250750149027552
# 87 -64 0.5 5500 0.02510678316839695
# 88 -76 0.5 1168 0.023527038525516002
# 88 -75 0.5 4432 0.01789526636049515
# 88 -74 0.5 5634 0.014313463808222252
# 88 -73 0.5 6486 0.025067929129638754
# 88 -72 0.5 10430 0.023760025996258254
# 88 -71 0.5 17025 0.018354483968127402
# 88 -70 0.5 16986 0.0278650102335517
# 88 -69 0.5 11965 0.0249896583877805
# 88 -68 0.5 9782 0.027155289862379
# 88 -67 0.5 7937 0.0272145312219196
# 88 -66 0.5 8248 0.0234590271047753
# 88 -65 0.5 6868 0.026233737240721502
# 88 -64 0.5 4831 0.0257824522172794
# 89 -76 0.5 971 0.0185982202548182
# 89 -75 0.5 3859 0.014901954568082501
# 89 -74 0.5 5559 0.0205971371067648
# 89 -73 0.5 6574 0.025124467657610252
# 89 -72 0.5 8540 0.02027324407800405
# 89 -71 0.5 12509 0.025057599058329303
# 89 -70 0.5 13019 0.027302528757867102
# 89 -69 0.5 10507 0.0259399080947144
# 89 -68 0.5 8737 0.0322148703890509
# 89 -67 0.5 8094 0.024027109848729952
# 89 -66 0.5 7177 0.024646609757286903
# 89 -65 0.5 5877 0.0273769366331289
# 89 -64 0.5 4525 0.026541626049832102
# 90 -76 0.5 845 0.017074561681126203
# 90 -75 0.5 3315 0.0169259072574297
# 90 -74 0.5 5412 0.024197502139223653
# 90 -73 0.5 6725 0.021813801258581303
# 90 -72 0.5 7814 0.020357972582737503
# 90 -71 0.5 9739 0.025985524313287902
# 90 -70 0.5 10041 0.0234936069049066
# 90 -69 0.5 9070 0.0307038339813953
# 90 -68 0.5 8490 0.0293543020135411
# 90 -67 0.5 8097 0.022704575280989802
# 90 -66 0.5 6644 0.027005610971314303
# 90 -65 0.5 5245 0.0264339820241333
# 90 -64 0.5 3863 0.028337607267928902
# 91 -76 0.5 708 0.011957016883469004
# 91 -75 0.5 2655 0.0208928307467161
# 91 -74 0.5 4921 0.024826284169139203
# 91 -73 0.5 6687 0.0206497344106034
# 91 -72 0.5 7780 0.02376436964445545
# 91 -71 0.5 8548 0.02389297131394365
# 91 -70 0.5 8516 0.02514146000606425
# 91 -69 0.5 7715 0.026184827101665302
# 91 -68 0.5 8863 0.029782121557585403
# 91 -67 0.5 8047 0.024618563090159404
# 91 -66 0.5 6526 0.03050378358190565
# 91 -65 0.5 4773 0.031461980519473305
# 91 -64 0.5 3158 0.02633171934747085

# %%
from astropy.table import Table

# %%
acat = Table(cat)

# %%
acat.write('LMCParallax.fits', format='fits')

# %%
distmed=np.median(1/acat['parallax'])
print(distmed)
# Out:
# 49.99999999999999

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(acat['ra'],acat['dec'],c=acat['parallax'])
fig.colorbar(sc)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(acat['ra'],acat['dec'],c=1/acat['parallax'],vmax=75)
fig.colorbar(sc)

# %%
maxdist=np.amax(1/acat['parallax'])
print(maxdist)
# Out:
# 341.46957381964035

# %%
mindist=np.amin(1/acat['parallax'])
print(mindist)
# Out:
# 31.041565212687527

# %%
#take theta and i found in paper and try to get a predication of what the distances should look like
#use center O from email

# %%
#ra-alpha #dec-delta #angdist-rho #phi-angpos #theta-zang #i-xang
racenter=81.9
deccenter= -69.866667 
distcenter=50
xang=34.7
zang=122.5+90

# %%
import cmath as math

# %%
angdist=math.acos(math.cos(dec)*math.cos(deccenter)*math.cos((ra)-(racenter))+math.sin(dec)*math.sin(deccenter))

# %%
angpos=math.acos((-math.cos(dec)*math.sin((ra)-(racenter)))/(math.sin(angdist)))

# %%
dist=((distcenter)*(math.cos(xang)))/(math.cos(xang)*math.cos(angdist)-math.sin(xang)*math.sin(angdist)*math.sin(angpos-zang))

# %%
ra=67
dec=-75

# %%
print(dist)
# Out:
# (158.10234544275343-0j)
