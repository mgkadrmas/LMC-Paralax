# %%
from dl import authClient as ac, queryClient as qc, storeClient as sc, helpers
import pylab as plt
import numpy as np
from astropy.io import fits

# %%
token=ac.login('mgkadrmas')

# %%
def LMCParallax (ra,dec,radius):
    #take query
    res=qc.query(token,sql='select * from gaia_dr2.gaia_source where q3c_radial_query(ra,dec,'+str(ra)+','+str(dec)+','+str(radius)+')')
    df=helpers.utils.convert(res,'table')
    good1 = (df['bp_rp'].data>=0.92) & (df['bp_rp'].data<=2.5) & (df['phot_g_mean_mag']<20.0) & (df['phot_g_mean_mag']>=(-5.0*df['bp_rp']+24.0)) & (df['phot_g_mean_mag']<=(-5.0*df['bp_rp']+27.0)) & (np.abs(df['parallax'])<=0.2)
    medpmra=np.median(df['pmra'][good1])
    medpmdec=np.median(df['pmdec'][good1])
    pndist=np.sqrt((df['pmra']-medpmra)**2 + (df['pmdec']-medpmdec)**2)
    good2 = (df['bp_rp'].data>=0.92) & (df['bp_rp'].data<=2.5) & (df['phot_g_mean_mag']<19.0) & (df['phot_g_mean_mag']>=(-5.0*df['bp_rp']+24.0)) & (df['phot_g_mean_mag']<=(-5.0*df['bp_rp']+27.0)) & (np.abs(df['parallax'])<=0.2) &(pndist<=2.0)
    medplx=np.median(df['parallax'][good2])+0.030112982075019102 #right mean distance? 
    ngood=np.sum(good2)
    print(ra, dec, radius, ngood, medplx)
    return (ngood, medplx)

# %%
radius=0.5
dtype = np.dtype([('ra',float),('dec',float),('radius',float),('ngood',int),('parallax',float)])
cat = np.zeros([25,13],dtype=dtype)
for i in range (25):
    ra=i+67
    for j in range (13):
        dec=j-76
        (ngood, medplx) = LMCParallax(ra,dec,radius) 
        cat[i,j]['ra']=ra
        cat[i,j]['dec']=dec
        cat[i,j]['radius']=radius
        cat[i,j]['ngood']=ngood
        cat[i,j]['parallax']=medplx
# Out:
# /data0/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater_equal
#   """
# /data0/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in less_equal
#   """
# /data0/sw/anaconda3/lib/python3.6/site-packages/astropy/table/column.py:965: RuntimeWarning: invalid value encountered in greater_equal
#   return getattr(self.data, op)(other)
# /data0/sw/anaconda3/lib/python3.6/site-packages/astropy/table/column.py:965: RuntimeWarning: invalid value encountered in less_equal
#   return getattr(self.data, op)(other)
# /data0/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in greater_equal
#   if __name__ == '__main__':
# /data0/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in less_equal
#   if __name__ == '__main__':
# 67 -76 0.5 286 0.021558689700189253
# 67 -75 0.5 711 0.0251415706450357
# 67 -74 0.5 1273 0.015969560427023903
# 67 -73 0.5 1961 0.0127590595593676
# 67 -72 0.5 2299 0.018615001963071302
# 67 -71 0.5 2288 0.015342110427128752
# 67 -70 0.5 2706 0.015186008855331851
# 67 -69 0.5 2747 0.016887255950181
# 67 -68 0.5 2445 0.019013789380360503
# 67 -67 0.5 1505 0.0258288180346246
# 67 -66 0.5 703 0.0190934112731988
# 67 -65 0.5 318 0.01950937591365705
# 67 -64 0.5 206 0.009082809328087502
# 68 -76 0.5 345 0.020462416815461203
# 68 -75 0.5 1035 0.0188669264347818
# 68 -74 0.5 1801 0.015167081469124702
# 68 -73 0.5 2586 0.014630378581483252
# 68 -72 0.5 3079 0.0228611407433471
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-63edf22af2fa> in <module>()
#       6     for j in range (13):
#       7         dec=j-76
# ----> 8         (ngood, medplx) = LMCParallax(ra,dec,radius)
#       9         cat[i,j]['ra']=ra
#      10         cat[i,j]['dec']=dec
#
# <ipython-input-6-835a2c09bd4e> in LMCParallax(ra, dec, radius)
#       1 def LMCParallax (ra,dec,radius):
#       2     #take query
# ----> 3     res=qc.query(token,sql='select * from gaia_dr2.gaia_source where q3c_radial_query(ra,dec,'+str(ra)+','+str(dec)+','+str(radius)+')')
#       4     df=helpers.utils.convert(res,'table')
#       5     good1 = (df['bp_rp'].data>=0.92) & (df['bp_rp'].data<=2.5) & (df['phot_g_mean_mag']<20.0) & (df['phot_g_mean_mag']>=(-5.0*df['bp_rp']+24.0)) & (df['phot_g_mean_mag']<=(-5.0*df['bp_rp']+27.0)) & (np.abs(df['parallax'])<=0.2)
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/noaodatalab-2.16.2-py3.6.egg/dl/Util.py in __call__(self, *args, **kw)
#      59         # Call the method instance with all original args/keywords and
#      60         # return the result.
# ---> 61         return function (*args, **kw)
#      62
#      63     def register(self, nargs, function, module):
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/noaodatalab-2.16.2-py3.6.egg/dl/queryClient.py in query(optval, adql, sql, fmt, out, async_, token, profile, **kw)
#     225         return qc_client._query (token=def_token(optval), adql=adql, sql=sql,
#     226                               fmt=fmt, out=out, async_=async_,
# --> 227                               profile=profile, **kw)
#     228
#     229
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/noaodatalab-2.16.2-py3.6.egg/dl/queryClient.py in _query(self, token, adql, sql, fmt, out, async_, profile, **kw)
#    1170
#    1171         # Make the service call.
# -> 1172         r = requests.get (dburl, headers=headers)
#    1173         if r.status_code != 200:
#    1174             raise queryClientError (r.text)
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      65
#      66     kwargs.setdefault('allow_redirects', True)
# ---> 67     return request('get', url, params=params, **kwargs)
#      68
#      69
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      51     # cases, and look like a memory leak in others.
#      52     with sessions.Session() as session:
# ---> 53         return session.request(method=method, url=url, **kwargs)
#      54
#      55
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     606
#     607         if not stream:
# --> 608             r.content
#     609
#     610         return r
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/requests/models.py in content(self)
#     735                     self._content = None
#     736                 else:
# --> 737                     self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     738
#     739             except AttributeError:
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/requests/models.py in generate()
#     658             if hasattr(self.raw, 'stream'):
#     659                 try:
# --> 660                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     661                         yield chunk
#     662                 except ProtocolError as e:
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/response.py in stream(self, amt, decode_content)
#     342         else:
#     343             while not is_fp_closed(self._fp):
# --> 344                 data = self.read(amt=amt, decode_content=decode_content)
#     345
#     346                 if data:
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     299             else:
#     300                 cache_content = False
# --> 301                 data = self._fp.read(amt)
#     302                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     303                     # Close the connection when no data is returned
#
# /data0/sw/anaconda3/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# /data0/sw/anaconda3/lib/python3.6/http/client.py in readinto(self, b)
#     491         # connection, and the user is reading more bytes than will be provided
#     492         # (for example, reading in 1k chunks)
# --> 493         n = self.fp.readinto(b)
#     494         if not n and b:
#     495             # Ideally, we would raise IncompleteRead if the content-length
#
# /data0/sw/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /data0/sw/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# /data0/sw/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /data0/sw/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from astropy.table import Table

# %%
acat = Table(cat)

# %%
acat.write('LMCParallax.fits', format='fits')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-a9b2abd60743> in <module>()
# ----> 1 acat.write('LMCParallax.fits', format='fits')
#
# NameError: name 'acat' is not defined

# %%
distmed=np.median(1/acat['parallax'])
print(distmed)
# Out:
# 49.99999999999999

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(acat['ra'],acat['dec'],c=acat['parallax'])
fig.colorbar(sc)

# %%
maxdist=np.amax(1/acat['parallax'])
print(maxdist)
# Out:
# 341.46957381964035

# %%
mindist=np.amin(1/acat['parallax'])
print(mindist)
# Out:
# 31.041565212687527

# %%
#take theta and i found in paper and try to get a predication of what the distances should look like
#use center O from email

# %%
#ra-alpha #dec-delta #angdist-rho #phi-angpos #theta-zang #i-xang
racenter=81.9*np.pi/180
deccenter= -69.866667*np.pi/180
distcenter=50
xang=34.7*np.pi/180
zang=(122.5+90)*np.pi/180

# %%
import cmath as math

# %%
angdist=np.arccos(np.cos(dec*np.pi/180)*np.cos(deccenter)*np.cos((ra*np.pi/180)-(racenter))+np.sin(dec*np.pi/180)*np.sin(deccenter))

# %%
angpos=np.arccos((-np.cos(dec*np.pi/180)*np.sin((ra*np.pi/180)-(racenter)))/(np.sin(angdist)))

# %%
dist=((distcenter)*(np.cos(xang)))/(np.cos(xang)*np.cos(angdist)-np.sin(xang)*np.sin(angdist)*np.sin(angpos-zang))

# %%
ra=67
dec=-75

# %%
print(dist)
# Out:
# 48.768237528615224

# %%
print(angdist)
# Out:
# 0.11844384456357211

# %%
print(angpos)
# Out:
# 0.9725516880691624

# %%
#run on all points make a map of distances

# %%
def preddist(ra,dec):
    racenter=81.9*np.pi/180
    deccenter= -69.866667*np.pi/180
    distcenter=50
    xang=34.7*np.pi/180
    zang=(122.5+90)*np.pi/180
    angdist=np.arccos(np.cos(dec*np.pi/180)*np.cos(deccenter)*np.cos((ra*np.pi/180)-(racenter))+np.sin(dec*np.pi/180)*np.sin(deccenter))
    angpos=np.arccos((-np.cos(dec*np.pi/180)*np.sin((ra*np.pi/180)-(racenter)))/(np.sin(angdist)))
    dist=((distcenter)*(np.cos(xang)))/(np.cos(xang)*np.cos(angdist)-np.sin(xang)*np.sin(angdist)*np.sin(angpos-zang))
    print(ra, dec, dist)
    return(dist)

# %%
dtype = np.dtype([('ra',float),('dec',float),('dist',float)])
dcat = np.zeros([25,13], dtype=dtype)
for i in range (25):
    ra=i+67
    for j in range (13):
        dec=j-76
        (dist) = preddist(ra,dec) 
        dcat[i,j]['ra']=ra
        dcat[i,j]['dec']=dec
        dcat[i,j]['dist']=dist
# Out:
# 67 -76 48.30040645435061
# 67 -75 48.768237528615224
# 67 -74 49.26037188206444
# 67 -73 49.77785741865544
# 67 -72 50.32182211933383
# 67 -71 50.89348082675464
# 67 -70 51.494142776991055
# 67 -69 51.884381501755946
# 67 -68 51.471379051187284
# 67 -67 51.08033640784756
# 67 -66 50.71052113356399
# 67 -65 50.36125246285133
# 67 -64 50.03189800912833
# 68 -76 48.23949089623592
# 68 -75 48.701805440704796
# 68 -74 49.188195318670445
# 68 -73 49.69969017997068
# 68 -72 50.23739821921871
# 68 -71 50.80251279118023
# 68 -70 51.39631975176302
# 68 -69 51.68902698031259
# 68 -68 51.27043851445659
# 68 -67 50.87394742914716
# 68 -66 50.49880605576563
# 68 -65 50.14431936052386
# 68 -64 49.80984155274814
# 69 -76 48.17774526623087
# 69 -75 48.63448182262374
# 69 -74 49.11506532217862
# 69 -73 49.620507156091044
# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(dcat['ra'],dcat['dec'],c=dcat['dist'])
fig.colorbar(sc)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(dcat['ra'],dcat['dec'],c=dcat['dist'])
fig.colorbar(sc)

# %%
racenter=81.9
deccenter= -69.866667
distcenter=50
inclin=27.81
pa=146.37

# %%
def dist2LMCtest(ra, dec, alph0, delt0, pa, io):
    ra1 = np.copy(ra)
    dec1 = np.copy(dec)
    ra1 = np.radians(ra1)
    dec1 = np.radians(dec1)
    alph0 = np.radians(alph0) #np.radians(82.25) #ra of LMC center
    delt0 = np.radians(delt0) #np.radians(-69.5) #dec of LMC center
    sd = np.sin(delt0)
    cd = np.cos(delt0)
    d0 = 49.9
    io = np.radians(io) #inclination #25.86
    pa = np.radians(pa+90) #np.radians(149.37+90)  #position angle of line-of-nodes
    cosr = cd*np.cos(dec1)*np.cos(ra1-alph0)+sd*np.sin(dec1)
    sinrcosph = -np.cos(dec1)*np.sin(ra1-alph0)
    sinrsinph = cd*np.sin(dec1)-sd*np.cos(dec1)*np.cos(ra1-alph0)
    dist = d0*np.cos(io)/(np.cos(io)*cosr-np.sin(io)*np.cos(pa)*sinrsinph+np.sin(io)*np.sin(pa)*sinrcosph)
    return dist

# %%
dtype = np.dtype([('ra',float),('dec',float),('dist',float)])
dcat = np.zeros([25,13], dtype=dtype)
for i in range (25):
    ra=i+67
    for j in range (13):
        dec=j-76
        (dist) = dist2LMCtest(ra,dec,racenter,deccenter,pa,inclin)
        dcat[i,j]['ra']=ra
        dcat[i,j]['dec']=dec
        dcat[i,j]['dist']=dist

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(dcat['ra'],dcat['dec'],c=dcat['dist'], cmap=plt.cm.seismic)
fig.colorbar(sc)

# %%
acat=fits.getdata('LMCParallax.fits')

# %%
pwd
# Out:
# '/home/jail/dlusers/mgkadrmas'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(acat['ra'],acat['dec'],c=1/acat['parallax'],vmax=75, cmap=plt.cm.seismic)
fig.colorbar(sc)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(acat['ra'],acat['dec'],c=1/acat['parallax'],vmax=54, vmin=47, cmap=plt.cm.seismic)
fig.colorbar(sc)

# %%
ls
# Out:
# LMC-ParallaxBroken.ipynb            LMCParallaxtest.fits
# LMCParallaxComparison .ipynb        notebooks/
# LMCParallax.fits                    notebooks-latest@
# LMCParallaxGraphs.ipynb             SMCParallax.ipynb
# LMCParallaxGraphsWrongOffset.ipynb  vospace@
# LMCParallaxNewOffset.ipynb

# %%
#plot the difference between these two graphs

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(acat['ra'],acat['dec'],c=dcat['dist']-(1/acat['parallax']), vmin=-75, cmap=plt.cm.seismic)
fig.colorbar(sc)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(acat['ra'],acat['dec'],c=((1/acat['parallax'])-dcat['dist']), cmap=plt.cm.seismic)
fig.colorbar(sc)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(dcat['ra'], dcat['dec'], c=((1/acat['parallax'])-dcat['dist']), vmax=75, cmap=plt.cm.seismic)
fig.colorbar(sc)
