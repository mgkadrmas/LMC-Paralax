# %% [markdown]
# In this Notebook:
#  - download and compile Gaia EDR3 data
#  - determine new two new cmd cuts, one with the RGB branch and one with both the RGB branch and AGB branch
#  - proper motion cut plot with all LMC stars (cmd cut applied)
#  - parallax vs. phot_g_mean_mag cut plot wiht all LMC stars (cmd and pm cuts applied)
#  - distances from binned_statistic_2d

# %%
import pylab as plt
import numpy as np
from astropy.io import fits
import matplotlib as mpl
import math
import astropy.io.fits as fits
from astropy.table import Table

# %%
bg = Table(fits.getdata ('LMC_query_EDR3-result.fits.gz'))

# %%
plt.figure(figsize=(12,6))
plt.scatter(bg['ra'], bg['dec'], c=bg['parallax'], s=0.01, vmin=0, vmax=0.4)
plt.colorbar()
plt.xlim([110,55])
plt.ylim([-80,-55])
plt.xlabel('ra [deg]')
plt.ylabel('dec [deg]')
plt.title('Milky Way Parallax [mas]')
# Out:
# Text(0.5,1,'Milky Way Parallax [mas]')

# %%
np.max(bg['ra'])
# Out:
# 73.05760695507492

# %%
bg2 = Table(fits.getdata ('LMC_query_EDR3_2-result.fits.gz'))

# %%
plt.figure(figsize=(12,6))
plt.scatter(bg2['ra'], bg2['dec'], c=bg2['parallax'], s=0.01, vmin=0, vmax=0.4)
plt.colorbar()
plt.xlim([110,55])
plt.ylim([-80,-55])
plt.xlabel('ra [deg]')
plt.ylabel('dec [deg]')
plt.title('Milky Way Parallax [mas]')
# Out:
# Text(0.5,1,'Milky Way Parallax [mas]')

# %%
np.max(bg2['ra'])
# Out:
# 75.77448020655808

# %%
bg3 = Table(fits.getdata('LMC_query_EDR3_3-result.fits.gz'))

# %%
np.max(bg3['ra'])
# Out:
# 77.85101376935386

# %%
plt.figure(figsize=(12,6))
plt.scatter(bg3['ra'], bg3['dec'], c=bg3['parallax'], s=0.01, vmin=0, vmax=0.4)
plt.colorbar()
plt.xlim([110,55])
plt.ylim([-80,-55])
plt.xlabel('ra [deg]')
plt.ylabel('dec [deg]')
plt.title('Milky Way Parallax [mas]')
# Out:
# Text(0.5,1,'Milky Way Parallax [mas]')

# %%
bg4 = Table(fits.getdata('LMC_query_EDR3_4-result.fits.gz'))

# %%
np.max(bg4['ra'])
# Out:
# 79.85882125650033

# %%
plt.figure(figsize=(12,6))
plt.scatter(bg4['ra'], bg4['dec'], c=bg4['parallax'], s=0.01, vmin=0, vmax=0.4)
plt.colorbar()
plt.xlim([110,55])
plt.ylim([-80,-55])
plt.xlabel('ra [deg]')
plt.ylabel('dec [deg]')
plt.title('Milky Way Parallax [mas]')
# Out:
# Text(0.5,1,'Milky Way Parallax [mas]')

# %%
bg5 = Table(fits.getdata('LMC_query_EDR3_5-result.fits.gz'))

# %%
np.max(bg5['ra'])
# Out:
# 81.81792230847923

# %%
plt.figure(figsize=(12,6))
plt.scatter(bg5['ra'], bg5['dec'], c=bg5['parallax'], s=0.01, vmin=0, vmax=0.4)
plt.colorbar()
plt.xlim([110,55])
plt.ylim([-80,-55])
plt.xlabel('ra [deg]')
plt.ylabel('dec [deg]')
plt.title('Milky Way Parallax [mas]')
# Out:
# Text(0.5,1,'Milky Way Parallax [mas]')

# %%
bg6 = Table(fits.getdata('LMC_query_EDR3_6-result.fits.gz'))

# %%
np.max(bg6['ra'])
# Out:
# 83.70535608693572

# %%
plt.figure(figsize=(12,6))
plt.scatter(bg6['ra'], bg6['dec'], c=bg6['parallax'], s=0.01, vmin=0, vmax=0.4)
plt.colorbar()
plt.xlim([110,55])
plt.ylim([-80,-55])
plt.xlabel('ra [deg]')
plt.ylabel('dec [deg]')
plt.title('Milky Way Parallax [mas]')
# Out:
# Text(0.5,1,'Milky Way Parallax [mas]')

# %%
bg7 = Table(fits.getdata('LMC_query_EDR3_7-result.fits.gz'))

# %%
np.max(bg7['ra'])
# Out:
# 85.96710807059387

# %%
plt.figure(figsize=(12,6))
plt.scatter(bg7['ra'], bg7['dec'], c=bg7['parallax'], s=0.01, vmin=0, vmax=0.4)
plt.colorbar()
plt.xlim([110,55])
plt.ylim([-80,-55])
plt.xlabel('ra [deg]')
plt.ylabel('dec [deg]')
plt.title('Milky Way Parallax [mas]')
# Out:
# Text(0.5,1,'Milky Way Parallax [mas]')

# %%
bg8 = Table(fits.getdata('LMC_query_EDR3_8-result.fits.gz'))

# %%
np.max(bg8['ra'])
# Out:
# 89.51639672843568

# %%
plt.figure(figsize=(12,6))
plt.scatter(bg8['ra'], bg8['dec'], c=bg8['parallax'], s=0.01, vmin=0, vmax=0.4)
plt.colorbar()
plt.xlim([110,55])
plt.ylim([-80,-55])
plt.xlabel('ra [deg]')
plt.ylabel('dec [deg]')
plt.title('Milky Way Parallax [mas]')
# Out:
# Text(0.5,1,'Milky Way Parallax [mas]')

# %%
bg9 = Table(fits.getdata('LMC_query_EDR3_9-result.fits.gz'))

# %%
np.max(bg9['ra'])
# Out:
# 98.09908171196268

# %%
plt.figure(figsize=(12,6))
plt.scatter(bg9['ra'], bg9['dec'], c=bg9['parallax'], s=0.01, vmin=0, vmax=0.4)
plt.colorbar()
plt.xlim([110,55])
plt.ylim([-80,-55])
plt.xlabel('ra [deg]')
plt.ylabel('dec [deg]')
plt.title('Milky Way Parallax [mas]')
# Out:
# Text(0.5,1,'Milky Way Parallax [mas]')

# %%
bg10 = Table(fits.getdata('LMC_query_EDR3_10-result.fits.gz'))

# %%
np.max(bg10['ra'])
# Out:
# 109.99999827135042

# %%
plt.figure(figsize=(12,6))
plt.scatter(bg10['ra'], bg10['dec'], c=bg10['parallax'], s=0.01, vmin=0, vmax=0.4)
plt.colorbar()
plt.xlim([110,55])
plt.ylim([-80,-55])
plt.xlabel('ra [deg]')
plt.ylabel('dec [deg]')
plt.title('Milky Way Parallax [mas]')
# Out:
# Text(0.5,1,'Milky Way Parallax [mas]')

# %%
bg.remove_columns(['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch', 'ra_dec_corr', 'ra_parallax_corr', 'ra_pmra_corr', 'ra_pmdec_corr', 'dec_parallax_corr', 'dec_pmra_corr', 'dec_pmdec_corr', 'parallax_pmra_corr', 'parallax_pmdec_corr', 'pmra_pmdec_corr', 'astrometric_n_obs_al', 'astrometric_n_obs_ac', 'astrometric_n_good_obs_al', 'astrometric_n_bad_obs_al', 'astrometric_gof_al', 'astrometric_chi2_al', 'astrometric_excess_noise', 'astrometric_excess_noise_sig', 'astrometric_params_solved', 'astrometric_primary_flag', 'nu_eff_used_in_astrometry', 'pseudocolour', 'pseudocolour_error', 'ra_pseudocolour_corr', 'dec_pseudocolour_corr', 'parallax_pseudocolour_corr', 'pmra_pseudocolour_corr', 'pmdec_pseudocolour_corr', 'astrometric_matched_transits', 'visibility_periods_used', 'astrometric_sigma5d_max', 'matched_transits', 'new_matched_transits', 'matched_transits_removed', 'ipd_gof_harmonic_amplitude', 'ipd_gof_harmonic_phase', 'ipd_frac_multi_peak', 'ipd_frac_odd_win', 'ruwe', 'scan_direction_strength_k1', 'scan_direction_strength_k2', 'scan_direction_strength_k3', 'scan_direction_strength_k4', 'scan_direction_mean_k1', 'scan_direction_mean_k2', 'scan_direction_mean_k3', 'scan_direction_mean_k4', 'duplicated_source', 'phot_g_n_obs', 'phot_g_mean_flux', 'phot_g_mean_flux_error', 'phot_g_mean_flux_over_error', 'phot_bp_n_obs', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error', 'phot_bp_mean_flux_over_error', 'phot_bp_mean_mag', 'phot_rp_n_obs', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error', 'phot_rp_mean_flux_over_error', 'phot_rp_mean_mag', 'phot_bp_n_contaminated_transits', 'phot_bp_n_blended_transits', 'phot_rp_n_contaminated_transits', 'phot_rp_n_blended_transits', 'phot_proc_mode', 'phot_bp_rp_excess_factor', 'bp_g', 'g_rp', 'dr2_radial_velocity', 'dr2_radial_velocity_error', 'dr2_rv_nb_transits', 'dr2_rv_template_teff', 'dr2_rv_template_logg', 'dr2_rv_template_fe_h', 'ecl_lon', 'ecl_lat'])

# %%
bg2.remove_columns(['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch', 'ra_dec_corr', 'ra_parallax_corr', 'ra_pmra_corr', 'ra_pmdec_corr', 'dec_parallax_corr', 'dec_pmra_corr', 'dec_pmdec_corr', 'parallax_pmra_corr', 'parallax_pmdec_corr', 'pmra_pmdec_corr', 'astrometric_n_obs_al', 'astrometric_n_obs_ac', 'astrometric_n_good_obs_al', 'astrometric_n_bad_obs_al', 'astrometric_gof_al', 'astrometric_chi2_al', 'astrometric_excess_noise', 'astrometric_excess_noise_sig', 'astrometric_params_solved', 'astrometric_primary_flag', 'nu_eff_used_in_astrometry', 'pseudocolour', 'pseudocolour_error', 'ra_pseudocolour_corr', 'dec_pseudocolour_corr', 'parallax_pseudocolour_corr', 'pmra_pseudocolour_corr', 'pmdec_pseudocolour_corr', 'astrometric_matched_transits', 'visibility_periods_used', 'astrometric_sigma5d_max', 'matched_transits', 'new_matched_transits', 'matched_transits_removed', 'ipd_gof_harmonic_amplitude', 'ipd_gof_harmonic_phase', 'ipd_frac_multi_peak', 'ipd_frac_odd_win', 'ruwe', 'scan_direction_strength_k1', 'scan_direction_strength_k2', 'scan_direction_strength_k3', 'scan_direction_strength_k4', 'scan_direction_mean_k1', 'scan_direction_mean_k2', 'scan_direction_mean_k3', 'scan_direction_mean_k4', 'duplicated_source', 'phot_g_n_obs', 'phot_g_mean_flux', 'phot_g_mean_flux_error', 'phot_g_mean_flux_over_error', 'phot_bp_n_obs', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error', 'phot_bp_mean_flux_over_error', 'phot_bp_mean_mag', 'phot_rp_n_obs', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error', 'phot_rp_mean_flux_over_error', 'phot_rp_mean_mag', 'phot_bp_n_contaminated_transits', 'phot_bp_n_blended_transits', 'phot_rp_n_contaminated_transits', 'phot_rp_n_blended_transits', 'phot_proc_mode', 'phot_bp_rp_excess_factor', 'bp_g', 'g_rp', 'dr2_radial_velocity', 'dr2_radial_velocity_error', 'dr2_rv_nb_transits', 'dr2_rv_template_teff', 'dr2_rv_template_logg', 'dr2_rv_template_fe_h', 'ecl_lon', 'ecl_lat'])
bg3.remove_columns(['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch', 'ra_dec_corr', 'ra_parallax_corr', 'ra_pmra_corr', 'ra_pmdec_corr', 'dec_parallax_corr', 'dec_pmra_corr', 'dec_pmdec_corr', 'parallax_pmra_corr', 'parallax_pmdec_corr', 'pmra_pmdec_corr', 'astrometric_n_obs_al', 'astrometric_n_obs_ac', 'astrometric_n_good_obs_al', 'astrometric_n_bad_obs_al', 'astrometric_gof_al', 'astrometric_chi2_al', 'astrometric_excess_noise', 'astrometric_excess_noise_sig', 'astrometric_params_solved', 'astrometric_primary_flag', 'nu_eff_used_in_astrometry', 'pseudocolour', 'pseudocolour_error', 'ra_pseudocolour_corr', 'dec_pseudocolour_corr', 'parallax_pseudocolour_corr', 'pmra_pseudocolour_corr', 'pmdec_pseudocolour_corr', 'astrometric_matched_transits', 'visibility_periods_used', 'astrometric_sigma5d_max', 'matched_transits', 'new_matched_transits', 'matched_transits_removed', 'ipd_gof_harmonic_amplitude', 'ipd_gof_harmonic_phase', 'ipd_frac_multi_peak', 'ipd_frac_odd_win', 'ruwe', 'scan_direction_strength_k1', 'scan_direction_strength_k2', 'scan_direction_strength_k3', 'scan_direction_strength_k4', 'scan_direction_mean_k1', 'scan_direction_mean_k2', 'scan_direction_mean_k3', 'scan_direction_mean_k4', 'duplicated_source', 'phot_g_n_obs', 'phot_g_mean_flux', 'phot_g_mean_flux_error', 'phot_g_mean_flux_over_error', 'phot_bp_n_obs', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error', 'phot_bp_mean_flux_over_error', 'phot_bp_mean_mag', 'phot_rp_n_obs', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error', 'phot_rp_mean_flux_over_error', 'phot_rp_mean_mag', 'phot_bp_n_contaminated_transits', 'phot_bp_n_blended_transits', 'phot_rp_n_contaminated_transits', 'phot_rp_n_blended_transits', 'phot_proc_mode', 'phot_bp_rp_excess_factor', 'bp_g', 'g_rp', 'dr2_radial_velocity', 'dr2_radial_velocity_error', 'dr2_rv_nb_transits', 'dr2_rv_template_teff', 'dr2_rv_template_logg', 'dr2_rv_template_fe_h', 'ecl_lon', 'ecl_lat'])
bg4.remove_columns(['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch', 'ra_dec_corr', 'ra_parallax_corr', 'ra_pmra_corr', 'ra_pmdec_corr', 'dec_parallax_corr', 'dec_pmra_corr', 'dec_pmdec_corr', 'parallax_pmra_corr', 'parallax_pmdec_corr', 'pmra_pmdec_corr', 'astrometric_n_obs_al', 'astrometric_n_obs_ac', 'astrometric_n_good_obs_al', 'astrometric_n_bad_obs_al', 'astrometric_gof_al', 'astrometric_chi2_al', 'astrometric_excess_noise', 'astrometric_excess_noise_sig', 'astrometric_params_solved', 'astrometric_primary_flag', 'nu_eff_used_in_astrometry', 'pseudocolour', 'pseudocolour_error', 'ra_pseudocolour_corr', 'dec_pseudocolour_corr', 'parallax_pseudocolour_corr', 'pmra_pseudocolour_corr', 'pmdec_pseudocolour_corr', 'astrometric_matched_transits', 'visibility_periods_used', 'astrometric_sigma5d_max', 'matched_transits', 'new_matched_transits', 'matched_transits_removed', 'ipd_gof_harmonic_amplitude', 'ipd_gof_harmonic_phase', 'ipd_frac_multi_peak', 'ipd_frac_odd_win', 'ruwe', 'scan_direction_strength_k1', 'scan_direction_strength_k2', 'scan_direction_strength_k3', 'scan_direction_strength_k4', 'scan_direction_mean_k1', 'scan_direction_mean_k2', 'scan_direction_mean_k3', 'scan_direction_mean_k4', 'duplicated_source', 'phot_g_n_obs', 'phot_g_mean_flux', 'phot_g_mean_flux_error', 'phot_g_mean_flux_over_error', 'phot_bp_n_obs', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error', 'phot_bp_mean_flux_over_error', 'phot_bp_mean_mag', 'phot_rp_n_obs', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error', 'phot_rp_mean_flux_over_error', 'phot_rp_mean_mag', 'phot_bp_n_contaminated_transits', 'phot_bp_n_blended_transits', 'phot_rp_n_contaminated_transits', 'phot_rp_n_blended_transits', 'phot_proc_mode', 'phot_bp_rp_excess_factor', 'bp_g', 'g_rp', 'dr2_radial_velocity', 'dr2_radial_velocity_error', 'dr2_rv_nb_transits', 'dr2_rv_template_teff', 'dr2_rv_template_logg', 'dr2_rv_template_fe_h', 'ecl_lon', 'ecl_lat'])
bg5.remove_columns(['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch', 'ra_dec_corr', 'ra_parallax_corr', 'ra_pmra_corr', 'ra_pmdec_corr', 'dec_parallax_corr', 'dec_pmra_corr', 'dec_pmdec_corr', 'parallax_pmra_corr', 'parallax_pmdec_corr', 'pmra_pmdec_corr', 'astrometric_n_obs_al', 'astrometric_n_obs_ac', 'astrometric_n_good_obs_al', 'astrometric_n_bad_obs_al', 'astrometric_gof_al', 'astrometric_chi2_al', 'astrometric_excess_noise', 'astrometric_excess_noise_sig', 'astrometric_params_solved', 'astrometric_primary_flag', 'nu_eff_used_in_astrometry', 'pseudocolour', 'pseudocolour_error', 'ra_pseudocolour_corr', 'dec_pseudocolour_corr', 'parallax_pseudocolour_corr', 'pmra_pseudocolour_corr', 'pmdec_pseudocolour_corr', 'astrometric_matched_transits', 'visibility_periods_used', 'astrometric_sigma5d_max', 'matched_transits', 'new_matched_transits', 'matched_transits_removed', 'ipd_gof_harmonic_amplitude', 'ipd_gof_harmonic_phase', 'ipd_frac_multi_peak', 'ipd_frac_odd_win', 'ruwe', 'scan_direction_strength_k1', 'scan_direction_strength_k2', 'scan_direction_strength_k3', 'scan_direction_strength_k4', 'scan_direction_mean_k1', 'scan_direction_mean_k2', 'scan_direction_mean_k3', 'scan_direction_mean_k4', 'duplicated_source', 'phot_g_n_obs', 'phot_g_mean_flux', 'phot_g_mean_flux_error', 'phot_g_mean_flux_over_error', 'phot_bp_n_obs', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error', 'phot_bp_mean_flux_over_error', 'phot_bp_mean_mag', 'phot_rp_n_obs', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error', 'phot_rp_mean_flux_over_error', 'phot_rp_mean_mag', 'phot_bp_n_contaminated_transits', 'phot_bp_n_blended_transits', 'phot_rp_n_contaminated_transits', 'phot_rp_n_blended_transits', 'phot_proc_mode', 'phot_bp_rp_excess_factor', 'bp_g', 'g_rp', 'dr2_radial_velocity', 'dr2_radial_velocity_error', 'dr2_rv_nb_transits', 'dr2_rv_template_teff', 'dr2_rv_template_logg', 'dr2_rv_template_fe_h', 'ecl_lon', 'ecl_lat'])
bg6.remove_columns(['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch', 'ra_dec_corr', 'ra_parallax_corr', 'ra_pmra_corr', 'ra_pmdec_corr', 'dec_parallax_corr', 'dec_pmra_corr', 'dec_pmdec_corr', 'parallax_pmra_corr', 'parallax_pmdec_corr', 'pmra_pmdec_corr', 'astrometric_n_obs_al', 'astrometric_n_obs_ac', 'astrometric_n_good_obs_al', 'astrometric_n_bad_obs_al', 'astrometric_gof_al', 'astrometric_chi2_al', 'astrometric_excess_noise', 'astrometric_excess_noise_sig', 'astrometric_params_solved', 'astrometric_primary_flag', 'nu_eff_used_in_astrometry', 'pseudocolour', 'pseudocolour_error', 'ra_pseudocolour_corr', 'dec_pseudocolour_corr', 'parallax_pseudocolour_corr', 'pmra_pseudocolour_corr', 'pmdec_pseudocolour_corr', 'astrometric_matched_transits', 'visibility_periods_used', 'astrometric_sigma5d_max', 'matched_transits', 'new_matched_transits', 'matched_transits_removed', 'ipd_gof_harmonic_amplitude', 'ipd_gof_harmonic_phase', 'ipd_frac_multi_peak', 'ipd_frac_odd_win', 'ruwe', 'scan_direction_strength_k1', 'scan_direction_strength_k2', 'scan_direction_strength_k3', 'scan_direction_strength_k4', 'scan_direction_mean_k1', 'scan_direction_mean_k2', 'scan_direction_mean_k3', 'scan_direction_mean_k4', 'duplicated_source', 'phot_g_n_obs', 'phot_g_mean_flux', 'phot_g_mean_flux_error', 'phot_g_mean_flux_over_error', 'phot_bp_n_obs', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error', 'phot_bp_mean_flux_over_error', 'phot_bp_mean_mag', 'phot_rp_n_obs', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error', 'phot_rp_mean_flux_over_error', 'phot_rp_mean_mag', 'phot_bp_n_contaminated_transits', 'phot_bp_n_blended_transits', 'phot_rp_n_contaminated_transits', 'phot_rp_n_blended_transits', 'phot_proc_mode', 'phot_bp_rp_excess_factor', 'bp_g', 'g_rp', 'dr2_radial_velocity', 'dr2_radial_velocity_error', 'dr2_rv_nb_transits', 'dr2_rv_template_teff', 'dr2_rv_template_logg', 'dr2_rv_template_fe_h', 'ecl_lon', 'ecl_lat'])
bg7.remove_columns(['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch', 'ra_dec_corr', 'ra_parallax_corr', 'ra_pmra_corr', 'ra_pmdec_corr', 'dec_parallax_corr', 'dec_pmra_corr', 'dec_pmdec_corr', 'parallax_pmra_corr', 'parallax_pmdec_corr', 'pmra_pmdec_corr', 'astrometric_n_obs_al', 'astrometric_n_obs_ac', 'astrometric_n_good_obs_al', 'astrometric_n_bad_obs_al', 'astrometric_gof_al', 'astrometric_chi2_al', 'astrometric_excess_noise', 'astrometric_excess_noise_sig', 'astrometric_params_solved', 'astrometric_primary_flag', 'nu_eff_used_in_astrometry', 'pseudocolour', 'pseudocolour_error', 'ra_pseudocolour_corr', 'dec_pseudocolour_corr', 'parallax_pseudocolour_corr', 'pmra_pseudocolour_corr', 'pmdec_pseudocolour_corr', 'astrometric_matched_transits', 'visibility_periods_used', 'astrometric_sigma5d_max', 'matched_transits', 'new_matched_transits', 'matched_transits_removed', 'ipd_gof_harmonic_amplitude', 'ipd_gof_harmonic_phase', 'ipd_frac_multi_peak', 'ipd_frac_odd_win', 'ruwe', 'scan_direction_strength_k1', 'scan_direction_strength_k2', 'scan_direction_strength_k3', 'scan_direction_strength_k4', 'scan_direction_mean_k1', 'scan_direction_mean_k2', 'scan_direction_mean_k3', 'scan_direction_mean_k4', 'duplicated_source', 'phot_g_n_obs', 'phot_g_mean_flux', 'phot_g_mean_flux_error', 'phot_g_mean_flux_over_error', 'phot_bp_n_obs', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error', 'phot_bp_mean_flux_over_error', 'phot_bp_mean_mag', 'phot_rp_n_obs', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error', 'phot_rp_mean_flux_over_error', 'phot_rp_mean_mag', 'phot_bp_n_contaminated_transits', 'phot_bp_n_blended_transits', 'phot_rp_n_contaminated_transits', 'phot_rp_n_blended_transits', 'phot_proc_mode', 'phot_bp_rp_excess_factor', 'bp_g', 'g_rp', 'dr2_radial_velocity', 'dr2_radial_velocity_error', 'dr2_rv_nb_transits', 'dr2_rv_template_teff', 'dr2_rv_template_logg', 'dr2_rv_template_fe_h', 'ecl_lon', 'ecl_lat'])
bg8.remove_columns(['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch', 'ra_dec_corr', 'ra_parallax_corr', 'ra_pmra_corr', 'ra_pmdec_corr', 'dec_parallax_corr', 'dec_pmra_corr', 'dec_pmdec_corr', 'parallax_pmra_corr', 'parallax_pmdec_corr', 'pmra_pmdec_corr', 'astrometric_n_obs_al', 'astrometric_n_obs_ac', 'astrometric_n_good_obs_al', 'astrometric_n_bad_obs_al', 'astrometric_gof_al', 'astrometric_chi2_al', 'astrometric_excess_noise', 'astrometric_excess_noise_sig', 'astrometric_params_solved', 'astrometric_primary_flag', 'nu_eff_used_in_astrometry', 'pseudocolour', 'pseudocolour_error', 'ra_pseudocolour_corr', 'dec_pseudocolour_corr', 'parallax_pseudocolour_corr', 'pmra_pseudocolour_corr', 'pmdec_pseudocolour_corr', 'astrometric_matched_transits', 'visibility_periods_used', 'astrometric_sigma5d_max', 'matched_transits', 'new_matched_transits', 'matched_transits_removed', 'ipd_gof_harmonic_amplitude', 'ipd_gof_harmonic_phase', 'ipd_frac_multi_peak', 'ipd_frac_odd_win', 'ruwe', 'scan_direction_strength_k1', 'scan_direction_strength_k2', 'scan_direction_strength_k3', 'scan_direction_strength_k4', 'scan_direction_mean_k1', 'scan_direction_mean_k2', 'scan_direction_mean_k3', 'scan_direction_mean_k4', 'duplicated_source', 'phot_g_n_obs', 'phot_g_mean_flux', 'phot_g_mean_flux_error', 'phot_g_mean_flux_over_error', 'phot_bp_n_obs', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error', 'phot_bp_mean_flux_over_error', 'phot_bp_mean_mag', 'phot_rp_n_obs', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error', 'phot_rp_mean_flux_over_error', 'phot_rp_mean_mag', 'phot_bp_n_contaminated_transits', 'phot_bp_n_blended_transits', 'phot_rp_n_contaminated_transits', 'phot_rp_n_blended_transits', 'phot_proc_mode', 'phot_bp_rp_excess_factor', 'bp_g', 'g_rp', 'dr2_radial_velocity', 'dr2_radial_velocity_error', 'dr2_rv_nb_transits', 'dr2_rv_template_teff', 'dr2_rv_template_logg', 'dr2_rv_template_fe_h', 'ecl_lon', 'ecl_lat'])
bg9.remove_columns(['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch', 'ra_dec_corr', 'ra_parallax_corr', 'ra_pmra_corr', 'ra_pmdec_corr', 'dec_parallax_corr', 'dec_pmra_corr', 'dec_pmdec_corr', 'parallax_pmra_corr', 'parallax_pmdec_corr', 'pmra_pmdec_corr', 'astrometric_n_obs_al', 'astrometric_n_obs_ac', 'astrometric_n_good_obs_al', 'astrometric_n_bad_obs_al', 'astrometric_gof_al', 'astrometric_chi2_al', 'astrometric_excess_noise', 'astrometric_excess_noise_sig', 'astrometric_params_solved', 'astrometric_primary_flag', 'nu_eff_used_in_astrometry', 'pseudocolour', 'pseudocolour_error', 'ra_pseudocolour_corr', 'dec_pseudocolour_corr', 'parallax_pseudocolour_corr', 'pmra_pseudocolour_corr', 'pmdec_pseudocolour_corr', 'astrometric_matched_transits', 'visibility_periods_used', 'astrometric_sigma5d_max', 'matched_transits', 'new_matched_transits', 'matched_transits_removed', 'ipd_gof_harmonic_amplitude', 'ipd_gof_harmonic_phase', 'ipd_frac_multi_peak', 'ipd_frac_odd_win', 'ruwe', 'scan_direction_strength_k1', 'scan_direction_strength_k2', 'scan_direction_strength_k3', 'scan_direction_strength_k4', 'scan_direction_mean_k1', 'scan_direction_mean_k2', 'scan_direction_mean_k3', 'scan_direction_mean_k4', 'duplicated_source', 'phot_g_n_obs', 'phot_g_mean_flux', 'phot_g_mean_flux_error', 'phot_g_mean_flux_over_error', 'phot_bp_n_obs', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error', 'phot_bp_mean_flux_over_error', 'phot_bp_mean_mag', 'phot_rp_n_obs', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error', 'phot_rp_mean_flux_over_error', 'phot_rp_mean_mag', 'phot_bp_n_contaminated_transits', 'phot_bp_n_blended_transits', 'phot_rp_n_contaminated_transits', 'phot_rp_n_blended_transits', 'phot_proc_mode', 'phot_bp_rp_excess_factor', 'bp_g', 'g_rp', 'dr2_radial_velocity', 'dr2_radial_velocity_error', 'dr2_rv_nb_transits', 'dr2_rv_template_teff', 'dr2_rv_template_logg', 'dr2_rv_template_fe_h', 'ecl_lon', 'ecl_lat'])
bg10.remove_columns(['solution_id', 'designation', 'source_id', 'random_index', 'ref_epoch', 'ra_dec_corr', 'ra_parallax_corr', 'ra_pmra_corr', 'ra_pmdec_corr', 'dec_parallax_corr', 'dec_pmra_corr', 'dec_pmdec_corr', 'parallax_pmra_corr', 'parallax_pmdec_corr', 'pmra_pmdec_corr', 'astrometric_n_obs_al', 'astrometric_n_obs_ac', 'astrometric_n_good_obs_al', 'astrometric_n_bad_obs_al', 'astrometric_gof_al', 'astrometric_chi2_al', 'astrometric_excess_noise', 'astrometric_excess_noise_sig', 'astrometric_params_solved', 'astrometric_primary_flag', 'nu_eff_used_in_astrometry', 'pseudocolour', 'pseudocolour_error', 'ra_pseudocolour_corr', 'dec_pseudocolour_corr', 'parallax_pseudocolour_corr', 'pmra_pseudocolour_corr', 'pmdec_pseudocolour_corr', 'astrometric_matched_transits', 'visibility_periods_used', 'astrometric_sigma5d_max', 'matched_transits', 'new_matched_transits', 'matched_transits_removed', 'ipd_gof_harmonic_amplitude', 'ipd_gof_harmonic_phase', 'ipd_frac_multi_peak', 'ipd_frac_odd_win', 'ruwe', 'scan_direction_strength_k1', 'scan_direction_strength_k2', 'scan_direction_strength_k3', 'scan_direction_strength_k4', 'scan_direction_mean_k1', 'scan_direction_mean_k2', 'scan_direction_mean_k3', 'scan_direction_mean_k4', 'duplicated_source', 'phot_g_n_obs', 'phot_g_mean_flux', 'phot_g_mean_flux_error', 'phot_g_mean_flux_over_error', 'phot_bp_n_obs', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error', 'phot_bp_mean_flux_over_error', 'phot_bp_mean_mag', 'phot_rp_n_obs', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error', 'phot_rp_mean_flux_over_error', 'phot_rp_mean_mag', 'phot_bp_n_contaminated_transits', 'phot_bp_n_blended_transits', 'phot_rp_n_contaminated_transits', 'phot_rp_n_blended_transits', 'phot_proc_mode', 'phot_bp_rp_excess_factor', 'bp_g', 'g_rp', 'dr2_radial_velocity', 'dr2_radial_velocity_error', 'dr2_rv_nb_transits', 'dr2_rv_template_teff', 'dr2_rv_template_logg', 'dr2_rv_template_fe_h', 'ecl_lon', 'ecl_lat'])

# %%
from astropy.table import vstack

# %%
df = vstack([bg, bg2, bg3, bg4, bg5, bg6, bg7, bg8, bg9, bg10])

# %%
df.write('LMC_EDR3.fits', format='fits')

# %%
df = Table(fits.getdata('LMC_EDR3.fits'))

# %%
df.remove_columns(['ra_error', 'dec_error', 'parallax_over_error', 'pmra_error', 'pmdec_error', 'l', 'b'])

# %%
fin = np.where(np.isfinite(df['phot_g_mean_mag']) & np.isfinite(df['bp_rp']) & np.isfinite(df['pmra']) & np.isfinite(df['pmdec']) & np.isfinite(df['parallax']) & np.isfinite(df['ra']) & np.isfinite(df['dec']))
df = df[fin]

# %%
df.write('LMC_EDR3_wo_cuts.fits', format='fits')

# %%
df = Table(fits.getdata('LMC_EDR3_wo_cuts.fits')) ### USE THIS ONE

# %%
plt.figure(figsize=(12,6))
plt.scatter(df['ra'], df['dec'], c=df['parallax'], s=0.01, vmin=0, vmax=0.4)
plt.colorbar()
plt.xlim([110,55])
plt.ylim([-80,-55])
plt.xlabel('ra [deg]')
plt.ylabel('dec [deg]')
plt.title('Milky Way Parallax [mas]')
# Out:
# Text(0.5,1,'Milky Way Parallax [mas]')

# %%
def roi_cut(xcut,ycut,x,y): 
    from matplotlib.path import Path
    tupVerts = list(zip(xcut,ycut))
    points = np.vstack((x,y)).T
    p = Path(tupVerts) # make a polygon
    inside = p.contains_points(points)
    ind, = np.where(~inside)
    cutind, = np.where(inside)
    return ind, cutind
    print (ind, cutind)

# %%
def onclick(event):
    print('%s click: button=%d, x=%d, y=%d, xdata=%f, ydata=%f' %
          ('double' if event.dblclick else 'single', event.button,
           event.x, event.y, event.xdata, event.ydata))

# %%
fig = plt.figure(figsize=(10,6))
plt.hist2d(df['bp_rp'], df['phot_g_mean_mag'], (300,300), norm=mpl.colors.LogNorm())
plt.colorbar()
plt.xlabel('BP-RP Color (mag)')
plt.ylabel('G-band Mean Magnitude (mag)')
plt.ylim(21,12)
plt.xlim(-2,4)
fig.canvas.mpl_connect('button_press_event', onclick)
#%matplotlib qt
# Out:
# 6
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py", line 387, in process
#     proxy(*args, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py", line 227, in __call__
#     return mtd(*args, **kwargs)
#   File "<ipython-input-8-476a5fd096a7>", line 4, in onclick
#     event.x, event.y, event.xdata, event.ydata))
# TypeError: must be real number, not NoneType
# single click: button=1, x=408, y=156, xdata=0.738710, ydata=19.246753
# single click: button=1, x=443, y=127, xdata=1.077419, ydata=19.811688
# single click: button=1, x=488, y=146, xdata=1.512903, ydata=19.441558
# single click: button=1, x=483, y=188, xdata=1.464516, ydata=18.623377
# single click: button=1, x=513, y=261, xdata=1.754839, ydata=17.201299
# single click: button=1, x=542, y=299, xdata=2.035484, ydata=16.461039
# single click: button=1, x=583, y=314, xdata=2.432258, ydata=16.168831
# ...

# %%
xcut = [0.738710, 1.077419, 1.512903, 1.68, 2.035484, 2.4, 2.432258, 1.929032, 1.764516, 1.45, 0.7]
ycut = [19.346753, 19.9, 19.441558, 18, 16.5, 16.1, 15.85, 15.487013, 15.603896, 16, 18.75]
x = df['bp_rp']
y = df['phot_g_mean_mag']

(ind, cutind) = roi_cut(xcut,ycut,x,y)

# %%
fig = plt.figure(figsize=(10,6))
plt.hist2d(df['bp_rp'][cutind], df['phot_g_mean_mag'][cutind], (300,300), norm=mpl.colors.LogNorm())
plt.colorbar()
plt.xlabel('BP-RP Color (mag)')
plt.ylabel('G-band Mean Magnitude (mag)')
plt.ylim(21,12)
plt.xlim(-2,4)

#%matplotlib inline
# Out:
# (-2, 4)

# %%
cut = []
for i in range(len(xcut)):
    cut.append([xcut[i], ycut[i]])

# %%
cut.append(cut[0])
x, y = zip(*cut)

# %%
fig = plt.figure(figsize=(10,6))
plt.hist2d(df['bp_rp'], df['phot_g_mean_mag'], (300,300), norm=mpl.colors.LogNorm())
plt.colorbar()
plt.plot(x, y, color='red')
plt.xlabel('BP-RP Color (mag)')
plt.ylabel('G-band Mean Magnitude (mag)')
plt.ylim(21,12)
plt.xlim(-2,4)

#plt.tight_layout()
plt.savefig('cmdcut')

# %%
dfcut1 = df[cutind] ## RGB cmd cut

# %%
xcut2 = [0.738710, 1.077419, 1.512903, 1.68, 2.035484, 2.4, 4, 3.9, 3, 2.15, 1.45, 0.7]
ycut2 = [19.346753, 19.9, 19.441558, 18, 16.5, 16.1, 16, 15.4, 14.9, 14.9, 16, 18.75]
x2 = df['bp_rp']
y2 = df['phot_g_mean_mag']

(ind2, cutind2) = roi_cut(xcut2,ycut2,x2,y2)

# %%
fig = plt.figure(figsize=(10,6))
plt.hist2d(df['bp_rp'][cutind2], df['phot_g_mean_mag'][cutind2], (300,300), norm=mpl.colors.LogNorm())
plt.colorbar()
plt.xlabel('BP-RP Color (mag)')
plt.ylabel('G-band Mean Magnitude (mag)')
plt.ylim(21,12)
plt.xlim(-2,4)

#%matplotlib inline
# Out:
# (-2, 4)

# %%
cut2 = []
for i in range(len(xcut2)):
    cut2.append([xcut2[i], ycut2[i]])

# %%
cut2.append(cut2[0])
x2, y2 = zip(*cut2)

# %%
fig = plt.figure(figsize=(10,6))
plt.hist2d(df['bp_rp'], df['phot_g_mean_mag'], (300,300), norm=mpl.colors.LogNorm())
plt.colorbar()
plt.plot(x2, y2, color='red')
plt.xlabel('BP-RP Color (mag)')
plt.ylabel('G-band Mean Magnitude (mag)')
plt.ylim(21,12)
plt.xlim(-2,4)

#plt.tight_layout()
plt.savefig('cmdcut2')

# %%
dfcut2 = df[cutind2] ## RGB and AGB cmd cut

# %%
medpmra1 = np.nanmedian(dfcut1['pmra'])
medpmdec1 = np.nanmedian(dfcut1['pmdec'])
pmdist1 = np.sqrt((dfcut1['pmra']-medpmra1)**2 + (dfcut1['pmdec']-medpmdec1)**2)

# %%
pmcut1 = np.where(pmdist1 <= 2.0)

# %%
fig = plt.figure(figsize=(6,4.5))
plt.hist2d(dfcut1['pmra'][pmcut1], dfcut1['pmdec'][pmcut1], (300,300), norm=mpl.colors.LogNorm())
plt.colorbar()
plt.xlabel('Proper Motion in Right Ascention (mas/yr)')
plt.ylabel('Proper Motion in Declination (mas/yr)')
#plt.xlim(-1,4)
#plt.ylim(-2,3)

plt.tight_layout()
plt.savefig('pmcut')

# %%
dfcut1 = dfcut1[pmcut1]

# %%
medpmra2 = np.nanmedian(dfcut2['pmra'])
medpmdec2 = np.nanmedian(dfcut2['pmdec'])
pmdist2 = np.sqrt((dfcut2['pmra']-medpmra2)**2 + (dfcut2['pmdec']-medpmdec2)**2)

# %%
pmcut2 = np.where(pmdist2 <= 2.0)

# %%
fig = plt.figure(figsize=(6,4.5))
plt.hist2d(dfcut2['pmra'][pmcut2], dfcut2['pmdec'][pmcut2], (300,300), norm=mpl.colors.LogNorm())
plt.colorbar()
plt.xlabel('Proper Motion in Right Ascention (mas/yr)')
plt.ylabel('Proper Motion in Declination (mas/yr)')
#plt.xlim(-1,4)
#plt.ylim(-2,3)

plt.tight_layout()

# %%
dfcut2 = dfcut2[pmcut2]

# %%
len(dfcut1)
# Out:
# 5818559

# %%
len(dfcut2)
# Out:
# 5846361

# %%
plt.figure(figsize=(10,6))
plt.hist2d(dfcut1['phot_g_mean_mag'],dfcut1['parallax'],(500,500), vmax=1000, norm=mpl.colors.LogNorm())
plt.colorbar()
plt.ylabel('Parallax (mas)')
plt.xlabel('G Band Mean Magnitude (mag)')
plt.ylim(-3,3)
# Out:
# (-3, 3)

# %%
plx1 = abs(dfcut1['parallax']) < 3*dfcut1['parallax_error']

# %%
plt.figure(figsize=(10,6))
plt.hist2d(dfcut1['phot_g_mean_mag'][plx1],dfcut1['parallax'][plx1],(500,500), vmax=1000, norm=mpl.colors.LogNorm())
plt.colorbar()
plt.ylabel('Parallax (mas)')
plt.xlabel('G Band Mean Magnitude (mag)')
plt.ylim(-3, 3)
# Out:
# (-3, 3)

# %%
fig = plt.figure(figsize=(10,3))
plt.tight_layout()
plt.xlabel('G Band Mean Magnitude (mag)')

plt.subplot(121)
plt.hist2d(dfcut1['phot_g_mean_mag'],dfcut1['parallax'],(500,500), vmax=1000, norm=mpl.colors.LogNorm())
plt.colorbar()
plt.ylabel('Parallax (mas)')
plt.xlabel('G Band Mean Magnitude (mag)')
plt.ylim(-3,3)

plt.subplot(122)
plt.hist2d(dfcut1['phot_g_mean_mag'][plx1],dfcut1['parallax'][plx1],(500,500), vmax=1000, norm=mpl.colors.LogNorm())
plt.colorbar()
plt.ylabel('Parallax (mas)')
plt.xlabel('G Band Mean Magnitude (mag)')
plt.ylim(-3,3)

plt.tight_layout()
plt.savefig('plxcut')

# %%
dfcut1 = dfcut1[plx1]

# %%
plt.figure(figsize=(10,6))
plt.hist2d(dfcut2['phot_g_mean_mag'],dfcut2['parallax'],(500,500), vmax=1000, norm=mpl.colors.LogNorm())
plt.colorbar()
plt.ylabel('Parallax (mas)')
plt.xlabel('G Band Mean Magnitude (mag)')
plt.ylim(-3,3)
# Out:
# (-3, 3)

# %%
plx2 = abs(dfcut2['parallax']) < 3*dfcut2['parallax_error']

# %%
plt.figure(figsize=(10,6))
plt.hist2d(dfcut2['phot_g_mean_mag'][plx2],dfcut2['parallax'][plx2],(500,500), vmax=1000, norm=mpl.colors.LogNorm())
plt.colorbar()
plt.ylabel('Parallax (mas)')
plt.xlabel('G Band Mean Magnitude (mag)')
plt.ylim(-3, 3)
# Out:
# (-3, 3)

# %%
dfcut2 = dfcut2[plx2]

# %%
df1 = Table(fits.getdata('LMC_EDR3_w_cut1.fits'))
df2 = Table(fits.getdata('LMC_EDR3_w_cut2.fits'))

# %%
from scipy.stats import binned_statistic_2d

# %%
Map1, xedge1, yedge1, bin1 = binned_statistic_2d(df1['ra'], df1['dec'], df1['parallax'], statistic='median', bins=(56,26))
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]

# %%
plt.figure(figsize=(12,6))
plt.imshow(1/(Map1.T + 0.02), aspect='auto', vmin=0, vmax=100, cmap=plt.cm.RdGy)
plt.xlim(55,0)
plt.ylim(0,25)
plt.colorbar()

# %%
Map1, xedge1, yedge1, bin1 = binned_statistic_2d(df1['ra'], df1['dec'], df1['parallax'], statistic='median', bins=(111,51))
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]

# %%
plt.figure(figsize=(12,6))
plt.imshow(1/(Map1.T + 0.02), aspect='auto', vmin=0, vmax=100, cmap=plt.cm.seismic)
plt.xlim(110,0)
plt.ylim(0,50)
plt.colorbar()
