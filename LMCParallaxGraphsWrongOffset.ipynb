# %%
from dl import authClient as ac, queryClient as qc, storeClient as sc, helpers
import pylab as plt
import numpy as np

# %%
token=ac.login('mgkadrmas')

# %%
def LMCParallax (ra,dec,radius):
    #take query
    res=qc.query(token,sql='select * from gaia_dr2.gaia_source where q3c_radial_query(ra,dec,'+str(ra)+','+str(dec)+','+str(radius)+')')
    df=helpers.utils.convert(res,'table')
    good1 = (df['bp_rp'].data>=0.92) & (df['bp_rp'].data<=2.5) & (df['phot_g_mean_mag']<20.0) & (df['phot_g_mean_mag']>=(-5.0*df['bp_rp']+24.0)) & (df['phot_g_mean_mag']<=(-5.0*df['bp_rp']+27.0)) & (np.abs(df['parallax'])<=0.2)
    medpmra=np.median(df['pmra'][good1])
    medpmdec=np.median(df['pmdec'][good1])
    pndist=np.sqrt((df['pmra']-medpmra)**2 + (df['pmdec']-medpmdec)**2)
    good2 = (df['bp_rp'].data>=0.92) & (df['bp_rp'].data<=2.5) & (df['phot_g_mean_mag']<19.0) & (df['phot_g_mean_mag']>=(-5.0*df['bp_rp']+24.0)) & (df['phot_g_mean_mag']<=(-5.0*df['bp_rp']+27.0)) & (np.abs(df['parallax'])<=0.2) &(pndist<=2.0)
    medplx=np.median(df['parallax'][good2])+0.052 #change offset to find right mean distance 
    ngood=np.sum(good2)
    print(ra, dec, radius, ngood, medplx)
    return (ngood, medplx)

# %%
radius=0.5
dtype = np.dtype([('ra',float),('dec',float),('radius',float),('ngood',int),('parallax',float)])
cat = np.zeros([25,13],dtype=dtype)
for i in range (67):
    ra=i+67
    for j in range (13):
        dec=j-76
        (ngood, medplx) = LMCParallax(ra,dec,radius) #what to do with returned values
        cat[i,j]['ra']=ra
        cat[i,j]['dec']=dec
        cat[i,j]['radius']=radius
        cat[i,j]['ngood']=ngood
        cat[i,j]['parallax']=medplx
# Out:
# /data0/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater_equal
#   """
# /data0/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in less_equal
#   """
# /data0/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in greater_equal
#   if __name__ == '__main__':
# /data0/sw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in less_equal
#   if __name__ == '__main__':
# 67 -76 0.5 286 0.04344570762517015
# 67 -75 0.5 711 0.0470285885700166
# 67 -74 0.5 1273 0.037856578352004795
# 67 -73 0.5 1961 0.034646077484348496
# 67 -72 0.5 2299 0.0405020198880522
# 67 -71 0.5 2288 0.03722912835210965
# 67 -70 0.5 2706 0.03707302678031275
# 67 -69 0.5 2747 0.0387742738751619
# 67 -68 0.5 2445 0.040900807305341395
# 67 -67 0.5 1505 0.0477158359596055
# 67 -66 0.5 703 0.040980429198179694
# 67 -65 0.5 318 0.04139639383863795
# 67 -64 0.5 206 0.030969827253068398
# 68 -76 0.5 345 0.0423494347404421
# 68 -75 0.5 1035 0.0407539443597627
# 68 -74 0.5 1801 0.037054099394105595
# 68 -73 0.5 2586 0.03651739650646415
# 68 -72 0.5 3079 0.044748158668328
# 68 -71 0.5 3459 0.0351674326241533
# 68 -70 0.5 4686 0.036506282134816395
# 68 -69 0.5 4440 0.036404466176215046
# 68 -68 0.5 3797 0.0404594518121284
# 68 -67 0.5 2427 0.0439764942694557
# 68 -66 0.5 1177 0.043999839259554696
# 90 -76 0.5 845 0.0389615796061071
# 90 -75 0.5 3315 0.0388129251824106
# 90 -74 0.5 5412 0.04608452006420455
# 90 -73 0.5 6725 0.043700819183562195
# 90 -72 0.5 7814 0.0422449905077184
# 90 -71 0.5 9739 0.0478725422382688
# 90 -70 0.5 10041 0.0453806248298875
# 90 -69 0.5 9070 0.0525908519063762
# 90 -68 0.5 8490 0.051241319938522
# 90 -67 0.5 8097 0.0445915932059707
# 90 -66 0.5 6644 0.0488926288962952
# 90 -65 0.5 5245 0.0483209999491142
# 90 -64 0.5 3863 0.050224625192909794
# 91 -76 0.5 708 0.0338440348084499
# 91 -75 0.5 2655 0.042779848671697
# 91 -74 0.5 4921 0.0467133020941201
# 91 -73 0.5 6687 0.042536752335584294
# 91 -72 0.5 7780 0.04565138756943635
# 91 -71 0.5 8548 0.04577998923892455
# 91 -70 0.5 8516 0.04702847793104515
# 91 -69 0.5 7715 0.0480718450266462
# 91 -68 0.5 8863 0.051669139482566295
# 91 -67 0.5 8047 0.046505581015140296
# 91 -66 0.5 6526 0.05239080150688655
# 91 -65 0.5 4773 0.0533489984444542
# 91 -64 0.5 3158 0.048218737272451746
# 92 -76 0.5 575 0.0403580692772309
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-941ad36d36e3> in <module>
#       7         dec=j-76
#       8         (ngood, medplx) = LMCParallax(ra,dec,radius) #what to do with returned values
# ----> 9         cat[i,j]['ra']=ra
#      10         cat[i,j]['dec']=dec
#      11         cat[i,j]['radius']=radius
#
# IndexError: index 25 is out of bounds for axis 0 with size 25

# %%
from astropy.table import Table

# %%
acat = Table(cat)

# %%
print(acat['ra'])
# Out:
#   ra [13]
# ------------
# 67.0 .. 67.0
# 68.0 .. 68.0
# 69.0 .. 69.0
# 70.0 .. 70.0
# 71.0 .. 71.0
# 72.0 .. 72.0
# 73.0 .. 73.0
# 74.0 .. 74.0
# 75.0 .. 75.0
# 76.0 .. 76.0
#          ...
# 81.0 .. 81.0
# 82.0 .. 82.0
# 83.0 .. 83.0
# 84.0 .. 84.0
# 85.0 .. 85.0
# 86.0 .. 86.0
# 87.0 .. 87.0
# 88.0 .. 88.0
# 89.0 .. 89.0
# 90.0 .. 90.0
# 91.0 .. 91.0
# Length = 25 rows

# %%
acat.write('LMCParallaxtest.fits', format='fits')

# %%
plt.scatter(acat['ra'], acat['dec'], c=acat['parallax'])
plt.colorbar()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(acat['ra'],acat['dec'],c=acat['parallax'])
fig.colorbar(sc)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('ra')
ax.set_ylabel('dec')
ax.set_xlim([92,65])
sc = ax.scatter(acat['ra'],acat['dec'],c=1/acat['parallax'])
fig.colorbar(sc)

# %%
distmed=np.median(1/acat['parallax'])

# %%
print (distmed)
# Out:
# 23.873745364040644

# %%
medplxtot=np.median(acat['parallax'])
print(medplxtot) #(79, -76)
# Out:
# 0.041887017924980896

# %%
#to get an average distance of 50kpc, average parallax needed is 1/50, from this, the median parallax (without offset) is subtacted from wanted value 
plxos=((1/50)-(medplxtot-0.052))
print(plxos)
# Out:
# 0.030112982075019102
