# %%
from dl import authClient as ac, queryClient as qc, storeClient as sc, helpers
import pylab as plt
import numpy as np

# %%
token=ac.login('mgkadrmas')

# %%
ra=13
dec=-73
rad=0.5

# %%
res=qc.query(token,sql='select * from gaia_dr2.gaia_source where q3c_radial_query(ra,dec,'+str(ra)+','+str(dec)+','+str(rad)+')')
df=helpers.utils.convert(res,'table')

# %%
plt.scatter(df['bp_rp'].data,df['phot_g_mean_mag'])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('bp_rp')
ax.set_ylabel('phot_g_mean_mag')
ax.set_ylim([22,8])
sc = ax.scatter(df['bp_rp'],df['phot_g_mean_mag'])

# %%
plt.hist2d(df['bp_rp'], df['phot_g_mean_mag'], bins=7)
# Out:
# /data0/sw/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# /data0/sw/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-3225c2cf4802> in <module>()
# ----> 1 plt.hist2d(df['bp_rp'], df['phot_g_mean_mag'], bins=7, cmap='Blues')
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist2d(x, y, bins, range, normed, weights, cmin, cmax, hold, data, **kwargs)
#    3153         ret = ax.hist2d(x, y, bins=bins, range=range, normed=normed,
#    3154                         weights=weights, cmin=cmin, cmax=cmax, data=data,
# -> 3155                         **kwargs)
#    3156     finally:
#    3157         ax._hold = washold
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist2d(self, x, y, bins, range, normed, weights, cmin, cmax, **kwargs)
#    6823
#    6824         h, xedges, yedges = np.histogram2d(x, y, bins=bins, range=range,
# -> 6825                                            normed=normed, weights=weights)
#    6826
#    6827         if cmin is not None:
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/numpy/lib/twodim_base.py in histogram2d(x, y, bins, range, normed, weights, density)
#     659         xedges = yedges = asarray(bins)
#     660         bins = [xedges, yedges]
# --> 661     hist, edges = histogramdd([x, y], bins, range, normed, weights, density)
#     662     return hist, edges[0], edges[1]
#     663
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py in histogramdd(sample, bins, range, normed, weights, density)
#     952                 raise ValueError(
#     953                     '`bins[{}]` must be positive, when an integer'.format(i))
# --> 954             smin, smax = _get_outer_edges(sample[:,i], range[i])
#     955             edges[i] = np.linspace(smin, smax, bins[i] + 1)
#     956         elif np.ndim(bins[i]) == 1:
#
# /data0/sw/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     259         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     260             raise ValueError(
# --> 261                 "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     262
#     263     # expand empty range to avoid divide by zero
#
# ValueError: autodetected range of [nan, nan] is not finite

# %%
print(df['bp_rp'])
# Out:
#    bp_rp
# ------------
#          nan
#          nan
#  0.108400345
#     0.919569
#          nan
#    0.4545517
#    1.2280369
#          nan
#          nan
# -0.059799194
#          ...
#          nan
#          nan
#          nan
#    0.5689888
#   0.46330452
#          nan
#          nan
#    0.9069557
#    0.3756218
#          nan
#   0.28998566
# Length = 660185 rows

# %%
print(df['phot_g_mean_mag'])
# Out:
# phot_g_mean_mag
# ---------------
#       20.590502
#       19.781532
#       19.958853
#       19.186676
#       20.451738
#        19.85539
#       17.472265
#        20.65742
#        20.69527
#       18.535418
#             ...
#        20.46958
#        20.26376
#       21.035988
#        19.59383
#       19.965626
#       20.782785
#       20.869839
#        17.99052
#       20.979448
#       20.570362
#       19.964096
# Length = 660185 rows
